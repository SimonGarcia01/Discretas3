# %% [markdown]
# # Intro to EDA with Python
# 1. Importing the pandas library and aliases it as pd.
# 2. Importing the datasets module from the sklearn library, a popular machine learning library in Python.
# 3. Loading the Iris dataset using datasets.load_iris(). The Iris dataset is a classic dataset in machine learning and contains measurements of iris flowers. It is often used for classification tasks.
#
# **Question, what does the Iris data set contains?**
# -- [Read](https://scikit-learn.org/1.4/auto_examples/datasets/plot_iris_dataset.html)
#
# ### What is a dataframe?
# A DataFrame is a two-dimensional labeled data structure in the pandas library for Python. It is similar to a spreadsheet or SQL table, where data is arranged in rows and columns. Each column in a DataFrame can have a different data type (e.g., integer, float, string) and is labeled with a unique name.

# %%
import pandas as pd
from sklearn import datasets

iris = datasets.load_iris()

print('keys', iris.target_names[0])

df = pd.DataFrame(data=iris.data,
   columns=iris.feature_names)
df['Species'] = iris.target
df.head(5)
# Out:
# keys setosa
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# The shape of a dataset refers to its dimensions, specifically the number of rows and columns it contains. In other words, the shape of a dataset indicates the size of the dataset in terms of its samples (rows) and features (columns)

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# The instruction `df.info()` is used in pandas to get a concise summary of a DataFrame. It provides information such as:
#
#
# *   The number of non-null entries in each column.
# *   The data type of each column.
# * The memory usage of the DataFrame.
# * Additional metadata, such as the DataFrame's index type.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Species            150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %% [markdown]
# The df.describe() method in pandas generates descriptive statistics of the numerical columns in a DataFrame. It provides useful summary statistics such as count, mean, standard deviation, minimum, maximum, and quartile values for each numerical column.

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     Species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %% [markdown]
# The expression df.isnull().sum() is used to count the number of missing values (NaN or None) in each column of a pandas DataFrame df. Here's how it works:
#
# 1. df.isnull() returns a DataFrame of the same shape as df, where each element is True if the corresponding element in df is null (missing), and False otherwise.
# 2. sum() then sums up the number of True values (i.e., missing values) in each column, because in Python, True is treated as 1 and False as 0 when summing.

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# Species              0
# dtype: int64

# %% [markdown]
# # Question
# Use the dataframe methods to understand what does the column Species contain, then execute the instructions described below and explain the results
#
#
# Instructions 1
#
# ```
# df.value_counts("Species")
# ```
# > Results and explanation
#
# Instructions 2
#
# ```
# import seaborn as sns
# import matplotlib.pyplot as plt
# sns.countplot(x='Species', data=df, )
# plt.show()
# ```
# > Results and explanation
#
# Instructions 3
#
#
# ```
# import seaborn as sns
# import matplotlib.pyplot as plt
# sns.pairplot(df, hue='Species', height=1.5)
#
# ```
# > Results and explanation
#
# Instructions 4
#
#
# ```
# import seaborn as sns
# import matplotlib.pyplot as plt
# plot = sns.FacetGrid(df, hue="Species")
# plot.map(sns.distplot, 'sepal length (cm)').add_legend()
# ```
# > Results and explanation

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df, hue='Species', height=1.5)

# %% [markdown]
# ## Correlation
# Correlation is a statistical measure that describes the relationship between two variables. It indicates the degree to which changes in one variable are associated with changes in another variable.
#
# **Key points about correlation:**
#
# * **Strength**: Correlation coefficients range from -1 to 1, where:
#   * 1 indicates a perfect positive correlation (as one variable increases, the other variable also increases).
#   * -1 indicates a perfect negative correlation (as one variable increases, the other variable decreases).
#   * 0 indicates no linear correlation (there is no systematic relationship between the variables).
# * **Direction:** The sign of the correlation coefficient (+ or -) indicates the direction of the relationship:
#   * Positive correlation: Both variables tend to increase or decrease together.
#   * Negative correlation: One variable tends to increase while the other tends to decrease, or vice versa.
# * **Independence:** Correlation does not imply causation. Even if two variables are strongly correlated, it does not necessarily mean that changes in one variable cause changes in the other.
# [a joke](https://pbs.twimg.com/media/EivJFCAUMAIUlVn.jpg)
#
# ## Heatmap
# A heatmap provides a visual representation of the correlation between different pairs of columns in the DataFrame. Positive correlations are indicated by lighter colors, while negative correlations are indicated by darker colors. A correlation coefficient close to 1 indicates a strong positive correlation, close to -1 indicates a strong negative correlation, and close to 0 indicates no correlation.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df.corr(method='pearson'), annot = True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='Species', data=df, )
plt.show()
